# %%
import main
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
resnet = main.resnet
resnet_robust = main.resnet_robust

# %%
from loss_feature import diff_plot_loss 
from train import cifar_test as test_dataset

# %%
diff_plot_loss(resnet,resnet_robust,test_dataset,num_data=3,num_direction=3,scope=0.1,interval=0.01,savename='(3-3-0.1-0.001-1.png',desc1='resnet',desc2='resnet_robust')
# Out:
# /home/yihan/moss/github/EhanW/advrob-cifar10/loss_feature.py:77: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbinches" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.savefig(savename,facecolor=(1,1,1),bbinches = 'tight')

# %%
diff_plot_loss()
